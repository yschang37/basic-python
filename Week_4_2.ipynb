# %%
type(int('1'))
# Out:
# int

# %%
int(1)
# Out:
# 1

# %%
type(int(1))
# Out:
# int

# %%
type(int("1"))
# Out:
# int

# %%
type(int(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-95884019c7e5> in <module>()
# ----> 1 type(int(a))
#
# NameError: name 'a' is not defined

# %% [markdown]
# # Video: Exceptions Examples

# %% [markdown]
# ![47.PNG](attachment:47.PNG)

# %%
while True:
    try:
        n = input("Please enter an integer")
        n = int(n)
        break
    except ValueError:
        print("Input not an integer; try again")
print("Correct input of an integer")

# %% [markdown]
# ![48.PNG](attachment:48.PNG)

# %%
data = []
file_name = input("Provide a name of a file of data")

try:
    fh = open(file_name, 'r')
except IOError:
    print('cannot open', file_name)
else:
    for new in fh:
        if new != '\n':
            addit = new[:-1].split(',')
            data.append(addit)
finally:
    fh.close() #close file even if fail
# Out:
# Provide a name of a file of dataaaa
# cannot open aaa
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5c06cb026704> in <module>()
#      12             data.append(addit)
#      13 finally:
# ---> 14     fh.close() #close file even if fail
#
# NameError: name 'fh' is not defined

# %% [markdown]
# ![49.PNG](attachment:49.PNG)

# %%
a=1

# %%
b=['1','2']

# %%
type(b)
# Out:
# list

# %%
c=[1,2,4]

# %%
type(c)
# Out:
# list

# %%
type(b[1])
# Out:
# str

# %%
type(c[1])
# Out:
# int
