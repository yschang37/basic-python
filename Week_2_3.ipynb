# %% [markdown]
# # Video: Keyword Arguments

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %%
def printName(firstName, lastName, reverse):
    if reverse:
        print(lastName + ', ' + firstName)
    else:
        print(firstName, lastName)

# %%
printName('YS', 'Chang', False)
# Out:
# YS Chang

# %%
def printName(firstName, lastName, reverse=False):
    if reverse:
        print(lastName + ', ' + firstName)
    else:
        print(firstName, lastName)

# %%
printName('YS', 'Chang')
# Out:
# YS Chang

# %%
printName('YS', 'Chang', True) # reverse value will change
# Out:
# Chang, YS

# %% [markdown]
# # Video: Specification

# %% [markdown]
# ![5.PNG](attachment:5.PNG)
#
# ### it is better to build the doc string because when you want to revise the code two years later, you would know what I thought at the building time

# %%
def is_even(i):
    """
    input i is positive interger
    Return True if the int is even, otherwise return False
    """
    print("Hi")
    return i%2==0

# %%
is_even(5)
# Out:
# Hi
# False

# %%
def foo(x, y = 5):
    def bar(x):
        return x + 1
    return bar(y * 2)
          
foo(3)
# Out:
# 11

# %%
str1 = 'exterminate!' 
str2 = 'number One - the larch'

# %%
str1.upper
# Out:
# <function str.upper>

# %%
str1.upper()
# Out:
# 'EXTERMINATE!'

# %%
str1
# Out:
# 'exterminate!'

# %%
str1.isupper()
# Out:
# False

# %%
str1.islower()
# Out:
# True

# %%
str2.capitalize()
# Out:
# 'Number one - the larch'

# %%
str2.swapcase()
# Out:
# 'NUMBER oNE - THE LARCH'

# %%
str1.index('e')
# Out:
# 0

# %%
str2.index('n')
# Out:
# 0

# %%
str2.find('e')
# Out:
# 4

# %%
str2.find('!')
# Out:
# -1

# %%
str1.count('e')
# Out:
# 3

# %%
str1 = str1.replace('e', '*') 
str1
# Out:
# '*xt*rminat*!'

# %%
str2.replace('one', 'seven')
# Out:
# 'number seven - the larch'
