# %% [markdown]
# # Video: Tuples

# %% [markdown]
# ![19.PNG](attachment:19.PNG)

# %%
te = ()

# %%
type(te)
# Out:
# tuple

# %% [markdown]
# ![20.PNG](attachment:20.PNG)

# %% [markdown]
# ![21.PNG](attachment:21.PNG)

# %%
def get_data(aTuple):
    nums = ()
    words = ()
    for t in aTuple:
        num = nums + (t[0],)
        if t[1] not in words:
            words = words + (t[1],)
    min_nums = min(nums)
    max_nums = max(nums)
    unique_words = len(words)
    return (min_nums, max_nums, unique_words)

(small, large, words) = get_data(((1, 'mine'),
                                 (3, 'yours'),
                                 (5, 'ours'),
                                 (7, 'mines')))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-e5792db397fc> in <module>()
#      14                                  (3, 'yours'),
#      15                                  (5, 'ours'),
# ---> 16                                  (7, 'mines')))
#
# <ipython-input-11-e5792db397fc> in get_data(aTuple)
#       6         if t[1] not in words:
#       7             words = words + (t[1],)
# ----> 8     min_nums = min(nums)
#       9     max_nums = max(nums)
#      10     unique_words = len(words)
#
# ValueError: min() arg is an empty sequence

# %%
a = (1,2,3,4,5)

# %%
a
# Out:
# (1, 2, 3, 4, 5)

# %%
min(a)
# Out:
# 1

# %%
max(a)
# Out:
# 5

# %% [markdown]
# # Video: Lists

# %% [markdown]
# ![22.PNG](attachment:22.PNG)

# %%
L=[1,3,5]

# %%
type(L)
# Out:
# list

# %%
L[2]=4

# %%
L
# Out:
# [1, 3, 4]

# %%
x = [1, 2, [3, 'John', 4], 'Hi']

# %%
x[0:1]
# Out:
# [1]

# %%
x[0:2]
# Out:
# [1, 2]

# %%
x[1:2]
# Out:
# [2]
