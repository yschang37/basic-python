# %% [markdown]
# # Video: Mutation, Aliasing, Cloning

# %%
warm = ['red', 'hot', 'not cool']

# %%
hot = warm

# %%
hot
# Out:
# ['red', 'hot', 'not cool']

# %%
warm.append('pink')

# %%
hot
# Out:
# ['red', 'hot', 'not cool', 'pink']

# %%
hot1 = warm[:]

# %%
hot1
# Out:
# ['red', 'hot', 'not cool', 'pink']

# %% [markdown]
# # clone

# %%
warm.append('oh no')

# %%
hot1
# Out:
# ['red', 'hot', 'not cool', 'pink']

# %%
hot1.sort()

# %%
hot1
# Out:
# ['hot', 'not cool', 'pink', 'red']

# %%
hot = ['red']

# %%
warm = ['orange', 'not cool']

# %%
hot.append(warm)

# %%
hot
# Out:
# ['red', ['orange', 'not cool']]

# %%
hot.append('red')

# %%
hot
# Out:
# ['red', ['orange', 'not cool'], 'red']

# %%
warm.append('pint') # this step tell me that when I change the warm , it also cause the hot to change

# %%
hot
# Out:
# ['red', ['orange', 'not cool', 'pint', 'pint'], 'red']

# %%
hot.append(hot)

# %%
hot
# Out:
# ['red', ['orange', 'not cool', 'pint', 'pint'], 'red', [...]]

# %%
print(hot)
# Out:
# ['red', ['orange', 'not cool', 'pint', 'pint'], 'red', [...]]

# %%
def remove_latter(L1,L2):
    for e in L1:
        if e in L2:
            L2.remove(e)

# %%
L1 = [1, 2, 3, 4, 5]

# %%
L2 = [4 , 4, 4, 5, 5, 5, 6, 6]

# %%
remove_latter(L1,L2)

# %%
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
L2 # remove 1 4 and 1 5
# Out:
# [4, 4, 5, 5, 6, 6]

# %%
remove_latter(L1,L2)

# %%
L2
# Out:
# [4, 5, 6, 6]

# %%
remove_latter(L1,L2)

# %%
L2
# Out:
# [6, 6]

# %%
remove_latter(L1,L2)

# %%
L2
# Out:
# [6, 6]

# %% [markdown]
# ![28.PNG](attachment:28.PNG)
