# %% [markdown]
# # Video: Inductive Reasoning

# %% [markdown]
# ![13.PNG](attachment:13.PNG)

# %% [markdown]
# # Video: Towers of Hanoi

# %% [markdown]
# ![14.PNG](attachment:14.PNG)

# %% [markdown]
# ![15.PNG](attachment:15.PNG)

# %%
def printMove(fr, to):
    print('move from' + str(fr)+" to " + str(to))
    
def Towers(n, fr, to, spare):
    if n == 1:
        printMove(fr, to)
    else:
        Towers(n-1, fr, spare, tp)
        Towers(1, fr, to, spare)
        Towers(n-1, spare, to, fr)

# %%
def gcdIter(a, b):
    temp=1
    small=1
    if a>b:
        small=b
    else:
        small=a
    
    for i in range(1,small+1):
        if (a%i==0) and (b%i==0):
            temp=i
            print(i)
    return temp

# %%
gcdIter(2, 4)
# Out:
# 1
# 2
# 2

# %% [markdown]
# # anothor method to get greatest common divisor

# %%
def gcdIter(a, b):
    '''
    a, b: positive integers
    
    returns: a positive integer, the greatest common divisor of a & b.
    '''
    testValue = min(a, b)

    # Keep looping until testValue divides both a & b evenly
    while a % testValue != 0 or b % testValue != 0:
        testValue -= 1

    return testValue

# %%
gcdIter(2, 4)
# Out:
# 2

# %%
def gcdIter(a, b):
    '''
    a, b: positive integers
    
    returns: a positive integer, the greatest common divisor of a & b.
    '''
    testValue = min(a, b)

    # Keep looping until testValue divides both a & b evenly
    while a % testValue != 0 or b % testValue != 0:
        testValue -= 1

    return testValue

# %% [markdown]
# # Video: Fibonacci

# %% [markdown]
# ![16.PNG](attachment:16.PNG)

# %% [markdown]
# ![17.PNG](attachment:17.PNG)

# %% [markdown]
# ![18.PNG](attachment:18.PNG)

# %%
def fib(x):
    """
    assume x an int >=0
    returns Fibonacci of x
    """
    if x == 0 or x == 1:
        return 1
    else:
        return fib(x-1)+fib(x-2)

# %%
fib(20)
# Out:
# 10946

# %%
print(pi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-9e2d2bd32686> in <module>()
# ----> 1 print(pi)
#
# NameError: name 'pi' is not defined
