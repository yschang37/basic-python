# %% [markdown]
# # Video: Introducing Functions

# %%
def is_even(i):
    """
    is a function to see 
    the interger is odd or even
    """
    print("hi")
    return i%2==0

is_even(3)
# Out:
# hi
# False

# %%
is_even(8)
# Out:
# hi
# True

# %%
def compare(x,y):
    """
    to compare the 
    number value
    """
    return x<y

# %%
compare(4,5)
# Out:
# True

# %%
def e(x, y, z):
   '''
   x: Can be int or float.
   y: Can be int or float.
   z: Can be int or float.
   '''
   return x >= y and x <= z

# %%
e(1,3,5)
# Out:
# False

# %%
e(1 1 1)
# Out:
#   File "<ipython-input-10-d88ce3a6f4ab>", line 1
#     e(1 1 1)
#         ^
# SyntaxError: invalid syntax

# %%
def square(a):
    """
    to have the square of a
    """
    c=a**2
    return c

# %%
square(8)
# Out:
# 64

# %%
def evalQuadratic(a, b, c, x):
    """
    eval quadratic
    """
    d=a*x**2+b*x+c
    return d

# %%
evalQuadratic(1,1,1,1)
# Out:
# 3

# %% [markdown]
# # Video: Calling Functions and Scope

# %%
def f(x):
    x=x+1
    print('in f(x):x =', x)
    
    return x

# %%
f(2)
# Out:
# in f(x):x = 3
# 3

# %%
x=2
print("aaaa",x,x,x,x,x)
# Out:
# aaaa 2 2 2 2 2

# %%
x=3
z=f(x)
# Out:
# in f(x):x = 4

# %%
x
# Out:
# 3

# %% [markdown]
# # if the function did not return the statement
# #### it will not return nothing

# %%
def is_even(i):
    """
    input interger i
    Does not return anything
    """
    i%2==0

# %% [markdown]
# ![44.PNG](attachment:44.PNG)

# %%
def func_a():
    print(" inside func_a")

# %%
def func_b(y):
    print(" inside func_b")
    return y

# %%
def func_c(z):
    print(" inside func_c")
    return z()

# %%
print(func_a())
print(5+func_b(2))
print(func_c(func_a)) #inside of  func_c must be function
                      #otherwise, it will have error
# Out:
#  inside func_a
# None
#  inside func_b
# 7
#  inside func_c
#  inside func_a
# None

# %%
print(func_c(5))
# Out:
#  inside func_c
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-56396b3da244> in <module>()
# ----> 1 print(func_c(5))
#
# <ipython-input-10-3b1a1ffac0ff> in func_c(z)
#       1 def func_c(z):
#       2     print(" inside func_c")
# ----> 3     return z()
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %%
def f(y):
    x=1
    x +=1
    print(x)
    
x = 5
f(x)
print(x)
# Out:
# 2
# 5

# %%
def g(y):
    print(x)
    print(x+1)
    
x=5
g(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
def h(y):
    x=x+1

x=5
h(x)
print(x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-20-dd75e48fc500> in <module>()
#       3
#       4 x=5
# ----> 5 h(x)
#       6 print(x)
#
# <ipython-input-20-dd75e48fc500> in h(y)
#       1 def h(y):
# ----> 2     x=x+1
#       3
#       4 x=5
#       5 h(x)
#
# UnboundLocalError: local variable 'x' referenced before assignment

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %%
def g(x):
    def h():
        x = 'abc'
        # no return, it means return nothing
    x = x + 1
    print('in g(x): x =', x)
    print(h())
    return x

x = 3
z = g(x)
# Out:
# in g(x): x = 4
# None

# %%
x
# Out:
# 3

# %%
h()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-3ddc75d5251c> in <module>()
# ----> 1 h()
#
# TypeError: h() missing 1 required positional argument: 'y'

# %%
z
# Out:
# 4

# %%
mult(1,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-238a5cd0bb96> in <module>()
# ----> 1 mult(1,2)
#
# NameError: name 'mult' is not defined
