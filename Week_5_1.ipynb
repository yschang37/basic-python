# %% [markdown]
# # Video: Object Oriented Programming

# %% [markdown]
# ![52.PNG](attachment:52.PNG)

# %% [markdown]
# ![53.PNG](attachment:53.PNG)

# %%
a = (1,3,4)

# %%
type(a)
# Out:
# tuple

# %% [markdown]
# # Video: Class Instances

# %% [markdown]
# ![66.PNG](attachment:66.PNG)

# %% [markdown]
# ![67.PNG](attachment:67.PNG)

# %% [markdown]
# ![65.PNG](attachment:65.PNG)

# %%
class Coordinate(object):
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def distance(self, other):
        x_diff_sq = (self.x-other.x)**2
        y_diff_sq = (self.y-other.y)**2
        return (x_diff_sq + y_diff_sq)**0.5
    def __str__(self):
        return "<" + str(self.x) + "," + str(self.y) + ">"
    def __sub__(self, other):
        return Coordinate(self.x - other.x, self.y - other.y)
        
Ex = Coordinate(3,3)

# %%
Ex.__str__()
# Out:
# '<3,3>'

# %%
c = Coordinate(3,4)
origin = Coordinate(0,0)

# %%
c.distance(origin) #know the distance between original
# Out:
# 5.0

# %%
print(c)
# Out:
# <3,4>

# %%
class Coordinate(object):
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def distance(self, other):
        x_diff_sq = (self.x-other.x)**2
        y_diff_sq = (self.x-other.y)**2
        return (x_diff_sq +y_diff_sq)**0.5
    def __str__(self):
        return "<" + str(self.x) + "," + str(self.y) + ">"
    def __sub__(self, other):
        return Coordinate(self.x - other.x, self.y - other.y)

# %%
c = Coordinate(3,4)
origin = Coordinate(0,0)

# %%
d = Coordinate

# %%
c

# %%
0x5e76be0
# Out:
# 99052512

# %%
0x5e76be0
# Out:
# 99052512

# %%
type(c)
# Out:
# __main__.Coordinate

# %%
print(isinstance(c,Coordinate))
# Out:
# True

# %%
isinstance(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-744d13d8d4d9> in <module>()
# ----> 1 isinstance(c)
#
# TypeError: isinstance expected 2 arguments, got 1

# %%
print(c.__str__(c))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-279946d12097> in <module>()
# ----> 1 print(c.__str__(c))
#
# TypeError: __str__() takes 1 positional argument but 2 were given

# %%
c-origin

# %%
print(c-origin)
# Out:
# <3,4>
