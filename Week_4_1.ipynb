# %% [markdown]
# # Video: Programming Challenges

# %% [markdown]
# ![54.PNG](attachment:54.PNG)

# %% [markdown]
# # Video: Classes of Tests

# %% [markdown]
# ![55.PNG](attachment:55.PNG)

# %% [markdown]
# ![56.PNG](attachment:56.PNG)

# %% [markdown]
# ![58.PNG](attachment:58.PNG)

# %% [markdown]
# # Video: Bugs

# %% [markdown]
# ![59.PNG](attachment:59.PNG)

# %%
def integerDivision(x, a):
    """
    x: a non-negative integer argument
    a: a positive integer argument

    returns: integer, the integer division of x divided by a.
    """
    count = 0
    while x >= a:
        count += 1
        x = x - a
    return count

# %%
print(integerDivision(5, 3))
# Out:
# 1

# %% [markdown]
# # Video: Debugging

# %% [markdown]
# ![41.PNG](attachment:41.PNG)

# %% [markdown]
# ![60.PNG](attachment:60.PNG)

# %%
def rem(x, a):
    """
    x: a non-negative integer argument
    a: a positive integer argument

    returns: integer, the remainder when x is divided by a.
    """
    if x == a:
        return 0
    elif x < a:
        return x
    else:
        return rem(x-a, a)

# %%
print(rem(60, 7))
# Out:
# 4

# %% [markdown]
# ![43.PNG](attachment:43.PNG)

# %% [markdown]
# ![44.PNG](attachment:44.PNG)

# %%
try:
    a = int(input("Tell me one number:"))
    b = int(input("Tell me another number:"))
    print(a/b)
    print("Okay")
except:
    print("Bug in user input")
print("Outside")
# Out:
# Tell me one number:1.1
# Bug in user input
# Outside

# %% [markdown]
# ![45.PNG](attachment:45.PNG)

# %%
try:
    a = int(input("Tell me one number:"))
    b = int(input("Tell me another number:"))
    print("a/b = ",a/b)
    print("a+b = ",a+b)
    
except ValueError:
    print("Can't convert to a number")
except ZeroDivisionError:
    print("Can't divide by zero")
except:
    print("Something went very wrong")
# Out:
# Tell me one number:1
# Tell me another number:3
# a/b =  0.3333333333333333
# a+b =  4

# %% [markdown]
# ![46.PNG](attachment:46.PNG)

# %% [markdown]
# ![42.PNG](attachment:42.PNG)

# %%
def rem(x, a):
    """
    x: a non-negative integer argument
    a: a positive integer argument

    returns: integer, the remainder when x is divided by a.
    """
    if x == a:
        return 0
    elif x < a:
        return x
    else:
        return rem(x-a, a)

# %%
rem(2, 5)
# Out:
# 2

# %%
rem(8, 5)
# Out:
# 3

# %%
def f(n):
   """
   n: integer, n >= 0.
   """
   if n == 0:
        return 1
   else:
        return n * f(n-1)

# %%
f(3)
# Out:
# 6

# %% [markdown]
# # Debugging Example

# %% [markdown]
# ![61.PNG](attachment:61.PNG)

# %%
def isPal(x):
    assert type(x) ==list
    temp = x[:]
    print(temp, x) # add print to see the structure
    temp.reverse()
    print(temp,x)
    if x == temp:
        return True
    else:
        return False
    
def silly(n):
    result = []
    for i in range(n):
        elem = input('Enter element: ')
        result.append(elem)
        print(result)
    if isPal(result):
        print('Yes')
    else:
        print('No')

# %%
silly(3)
# Out:
# Enter element: 1
# ['1']
# Enter element: 2
# ['1', '2']
# Enter element: 3
# ['1', '2', '3']
# ['1', '2', '3'] ['1', '2', '3']
# ['3', '2', '1'] ['1', '2', '3']
# No

# %%
result = []

for i in range(5):
        elem = input('Enter element: ')
        result.append(elem)
        print(result)

# %%
result = []

for i in range(5):
        elem = input('Enter element: ')
        result.append(elem)
        print(result)
# Out:
# Enter element: 1
# ['1']
# Enter element: 2
# ['1', '2']
# Enter element: 3
# ['1', '2', '3']
# Enter element: 4
# ['1', '2', '3', '4']
# Enter element: 5
# ['1', '2', '3', '4', '5']

# %%
print(result)
# Out:
# ['1', '2', '3', '4', '5']

# %%
result.reverse()

# %%
print(result)
# Out:
# ['5', '4', '3', '2', '1']
