# %% [markdown]
# # Video: Quick Review

# %% [markdown]
# ![33.PNG](attachment:33.PNG)

# %%
a = '1223'

# %%
a
# Out:
# '1223'

# %%
type(a)
# Out:
# str

# %%
a = [1, 3, 4]

# %%
a
# Out:
# [1, 3, 4]

# %%
type(a)
# Out:
# list

# %%
a = (1,2,3)

# %%
a
# Out:
# (1, 2, 3)

# %%
type(a)
# Out:
# tuple

# %%
a = range(4)

# %%
a
# Out:
# range(0, 4)

# %%
type(a)
# Out:
# range

# %% [markdown]
# # Video Dictionaries

# %% [markdown]
# ![34.PNG](attachment:34.PNG)

# %% [markdown]
# ![35.PNG](attachment:35.PNG)

# %% [markdown]
# ![38.PNG](attachment:38.PNG)

# %%
grades = {'1':'A+', '2':'B', '3':'A', '4':'C'}

# %%
grades['1']
# Out:
# 'A+'

# %%
grades['5']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-712bca9b0f87> in <module>()
# ----> 1 grades['5']
#
# KeyError: '5'

# %%
grades['5'] = 'B++'

# %%
grades['5']
# Out:
# 'B++'

# %%
'6' in grades
# Out:
# False

# %%
'5' in grades
# Out:
# True

# %%
del(grades['1'])

# %%
grades['1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-9ea6d7832037> in <module>()
# ----> 1 grades['1']
#
# KeyError: '1'

# %%
grades
# Out:
# {'2': 'B', '3': 'A', '4': 'C', '5': 'B++'}

# %%
grades.keys
# Out:
# <function dict.keys>

# %%
grades.keys()
# Out:
# dict_keys(['2', '3', '4', '5'])

# %%
grades.values()
# Out:
# dict_values(['B', 'A', 'C', 'B++'])

# %% [markdown]
# ![39.PNG](attachment:39.PNG)

# %% [markdown]
# ![40.PNG](attachment:40.PNG)

# %%
ani={'a': 'aardvark', 'b': 'baboon', 'c': 'coati', 'd':'donkey'}

# %%
len(ani)
# Out:
# 4

# %%
'baboon' in ani
# Out:
# False

# %%
ani.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
ani.values()
# Out:
# dict_values(['aardvark', 'baboon', 'coati', 'donkey'])

# %%
 len(ani['a'])
# Out:
# 8

# %%
animals = { 'a': ['aardvark'], 'b': ['baboon'], 'c': ['coati']}

animals['d'] = ['donkey']
animals['d'].append('dog')
animals['d'].append('dingo')

# %%
animals
# Out:
# {'a': ['aardvark'],
#  'b': ['baboon'],
#  'c': ['coati'],
#  'd': ['donkey', 'dog', 'dingo']}

# %%
def how_many(aDict):
    num = 0
    result = 0
    for k in aDict:
        result += len(aDict[k])
    return result

# %%
len(animals)
# Out:
# 4

# %%
for k in animals:
    print(animals[k])
# Out:
# ['aardvark']
# ['baboon']
# ['coati']
# ['donkey', 'dog', 'dingo']

# %%
len(animals['d'])
# Out:
# 3

# %%
how_many(animals)
# Out:
# 6
