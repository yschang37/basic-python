# %% [markdown]
# # Video: List Operations

# %% [markdown]
# ![23.PNG](attachment:23.PNG)

# %%
L = [1,2,3]

# %%
L1 = [4, 5, 6]

# %%
L+L1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
L.extend([4, 5, 6])

# %%
L
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
del(L[0])

# %%
L
# Out:
# [2, 3, 4, 5, 6]

# %% [markdown]
# ![24.PNG](attachment:24.PNG)

# %%
L.remove(3)

# %%
L
# Out:
# [2, 4, 5, 6]

# %%
L.pop()
# Out:
# 6

# %%
L
# Out:
# [2, 4, 5]

# %%
s = 'abc'

# %%
s = list(s)

# %%
s
# Out:
# ['a', 'b', 'c']
